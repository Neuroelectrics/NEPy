# %%
nepypath = input('NEpy repository path: \n ')
datapath = input('Data path: \n ')
# Out:
# NEpy repository path:
#  C:\Users\roser.sanchez\Documents\Git\nepy_support
# Data path:
#  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata

# %%
import sys
import os
import time
sys.path.append(nepypath)
import nepy as ne
import nepy.capsule.capsule as capsule
# %load_ext autoreload
# %autoreload 2
print("______________________________________________________________")
print ("\nNotebook started:", time.strftime("%Y-%m-%d %H:%M"))
print("\nData located in this folder:",'\033[93m', datapath, '\033[0m')
os.listdir(datapath)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ______________________________________________________________
#
# Notebook started: 2018-11-05 12:06
#
# Data located in this folder:  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata
# ['20170807135459_W012_V1_EYC.easy.gz',
#  '20170807135459_W012_V1_EYC.info',
#  '20170807135459_W012_V1_EYC_noinfo_s.easy.gz',
#  'test_file.txt']

# %%
filename = input('Copy paste the file you want to read (.easy / .easy.gz): \n')
filepath = os.path.join(datapath,filename)
# Out:
# Copy paste the file you want to read (.easy / .easy.gz):
# 20170807135459_W012_V1_EYC_noinfo_s.easy.gz

# %%
c = capsule.Capsule(filepath)
# Out:
# Found the file: C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s.easy.gz
# Initializing in file path:   C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s.easy.gz
# Processing:  20170807135459_W012_V1_EYC_noinfo_s
# Filenameroot:  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s
# Extension:  easy.gz
#
# _______________________________________________________________
# Reading info file ...
#  Warning! .info file not found! Using standard values...
# Reading  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s.easy.gz to get numchannels....
#
# numchannels ....... 32
# _______________________________________________________________
# Reading: 20170807135459_W012_V1_EYC_noinfo_s . easy.gz
#
# Number of channels detected: 32
# First sample recorded : 2017-08-07 19:54:50
#
#  L0 raw data data in uV
#                 Ch1           Ch2           Ch3           Ch4           Ch5  \
# count  59999.000000  59999.000000  59999.000000  59999.000000  59999.000000
# mean    5196.090108   8483.534711  13862.587896  -3698.596639   1387.191955
# std      281.873353    721.244344    269.087075     42.858447    227.039813
# min     4682.016000   7201.195000  13368.083000  -3851.986000    976.038000
# 25%     4965.520000   7882.810000  13641.048500  -3727.627000   1179.051000
# 50%     5167.627000   8436.394000  13841.344000  -3696.251000   1356.125000
# 75%     5439.806000   9089.852000  14093.138000  -3666.735000   1590.490000
# max     5768.538000   9842.778000  14427.472000  -3585.911000   1877.498000
#
#                 Ch6           Ch7           Ch8           Ch9          Ch10  \
# count  59999.000000  59999.000000  59999.000000  59999.000000  59999.000000
# mean   -8180.259534   6456.797619   2607.779962  -6539.911683   7869.947988
# std      129.571760    124.451898    219.699893    103.691028    225.437868
# min    -8420.325000   6236.029000   2171.230000  -6710.673000   7432.413000
# 25%    -8288.241000   6344.080000   2428.674000  -6624.174000   7707.262000
# 50%    -8202.935000   6446.648000   2592.325000  -6570.292000   7860.375000
# 75%    -8069.277000   6557.846000   2779.078000  -6466.818000   8063.984000
# max    -7867.957000   6728.792000   3067.922000  -6237.221000   8310.462000
#
#            ...               Ch29          Ch30          Ch31          Ch32  \
# count      ...       59999.000000  59999.000000  59999.000000  59999.000000
# mean       ...        3546.136027   2809.130150   9888.086205   1922.718791
# std        ...         215.238847    622.597106    167.542136     92.569278
# min        ...        3222.942000   1632.642000   9617.282000   1730.871000
# 25%        ...        3361.750000   2291.751000   9744.120000   1845.407000
# 50%        ...        3478.956000   2820.349000   9850.455000   1906.776000
# 75%        ...        3709.030000   3348.517000  10006.381000   1999.187000
# max        ...        4055.548000   3874.397000  10354.138000   2156.400000
#
#                  ax            ay           az  markers     unix_time  \
# count  59999.000000  59999.000000  59999.00000  59999.0  5.999900e+04
# mean    -316.446774   8154.400990  -4132.20237      0.0  1.502129e+12
# std      159.261022    208.701005    223.12616      0.0  3.464073e+04
# min    -1108.000000      0.000000  -5275.00000      0.0  1.502128e+12
# 25%     -411.000000   8061.000000  -4275.00000      0.0  1.502129e+12
# 50%     -304.000000   8178.000000  -4128.00000      0.0  1.502129e+12
# 75%     -225.000000   8257.000000  -4010.00000      0.0  1.502129e+12
# max      343.000000   9100.000000      0.00000      0.0  1.502129e+12
#
#                   t
# count  59999.000000
# mean      59.998000
# std       34.640727
# min        0.000000
# 25%       29.999000
# 50%       59.998000
# 75%       89.997000
# max      119.996000
#
# [8 rows x 38 columns]

# %%
c
# Out:
# Capsule attributes:
#
# - PSD :
#  None
#
#
# - Q :
#  None
#
#
# - author :
#  anonymous
#
#
# - badRecords :
#  None
#
#
# - basename :
#  20170807135459_W012_V1_EYC_noinfo_s
#
#
# - capsuledate :
#  2018-11-05 11:21
#
#
# - detrendtime :
#  None
#
#
# - eegstartdate :
#  2017-08-07 19:54:50
#
#
# - electrodes :
#  ['Ch1', 'Ch2', 'Ch3', 'Ch4', 'Ch5', 'Ch6', 'Ch7', 'Ch8', 'Ch9', 'Ch10', 'Ch11', 'Ch12', 'Ch13', 'Ch14', 'Ch15', 'Ch16', 'Ch17', 'Ch18', 'Ch19', 'Ch20', 'Ch21', 'Ch22', 'Ch23', 'Ch24', 'Ch25', 'Ch26', 'Ch27', 'Ch28', 'Ch29', 'Ch30', 'Ch31', 'Ch32']
#
#
# - fH :
#  None
#
#
# - fL :
#  None
#
#
# - filenameroot :
#  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s
#
#
# - filepath :
#  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s.easy.gz
#
#
# - fline :
#  None
#
#
# - fs :
#  500.0
#
#
# - good_init :
#  True
#
#
# - log :
#  ['capsule created: 2018-11-05 11:21']
#
#
# - np_acc :
#  [[    0.     0.     0.]
#  [    0.     0.     0.]
#  [    0.     0.     0.]
#  ...
#  [ -147.  8178. -3746.]
#  [ -147.  8178. -3746.]
#  [ -147.  8178. -3746.]]
#
#
# - np_eeg :
#  [[ 5706.549  9787.703 14372.541 ...  3827.381 10299.969  2095.318]
#  [ 5725.813  9811.545 14395.858 ...  3836.632 10319.377  2114.963]
#  [ 5743.933  9831.429 14416.791 ...  3852.892 10339.928  2131.748]
#  ...
#  [ 4710.627  7230.473 13397.552 ...  1661.682  9651.614  1771.021]
#  [ 4708.338  7225.323 13391.448 ...  1651.811  9646.13   1765.251]
#  [ 4716.015  7233.572 13401.176 ...  1652.05   9654.761  1772.594]]
#
#
# - np_eeg_original :
#  [[ 5706.549  9787.703 14372.541 ...  3827.381 10299.969  2095.318]
#  [ 5725.813  9811.545 14395.858 ...  3836.632 10319.377  2114.963]
#  [ 5743.933  9831.429 14416.791 ...  3852.892 10339.928  2131.748]
#  ...
#  [ 4710.627  7230.473 13397.552 ...  1661.682  9651.614  1771.021]
#  [ 4708.338  7225.323 13391.448 ...  1651.811  9646.13   1765.251]
#  [ 4716.015  7233.572 13401.176 ...  1652.05   9654.761  1772.594]]
#
#
# - np_markers :
#  [0. 0. 0. ... 0. 0. 0.]
#
#
# - np_stim :
#  []
#
#
# - np_time :
#  [0.00000e+00 2.00000e-03 4.00000e-03 ... 1.19992e+02 1.19994e+02
#  1.19996e+02]
#
#
# - num_channels :
#  32
#
#
# - offsets :
#  None
#
#
# - reference_electrodes :
#  None
#
#
# - sigmas :
#  None
# Capsule object created by anonymous on 2018-11-05 11:21 from file:
#
#             - C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s.easy.gz
#
# Current log is:
#
#             - ['capsule created: 2018-11-05 11:21']

# %%
print(c)
# Out:
# Capsule attributes:
#
# - PSD :
#  None
#
#
# - Q :
#  None
#
#
# - author :
#  anonymous
#
#
# - badRecords :
#  None
#
#
# - basename :
#  20170807135459_W012_V1_EYC_noinfo_s
#
#
# - capsuledate :
#  2018-11-05 11:21
#
#
# - detrendtime :
#  None
#
#
# - eegstartdate :
#  2017-08-07 19:54:50
#
#
# - electrodes :
#  ['Ch1', 'Ch2', 'Ch3', 'Ch4', 'Ch5', 'Ch6', 'Ch7', 'Ch8', 'Ch9', 'Ch10', 'Ch11', 'Ch12', 'Ch13', 'Ch14', 'Ch15', 'Ch16', 'Ch17', 'Ch18', 'Ch19', 'Ch20', 'Ch21', 'Ch22', 'Ch23', 'Ch24', 'Ch25', 'Ch26', 'Ch27', 'Ch28', 'Ch29', 'Ch30', 'Ch31', 'Ch32']
#
#
# - fH :
#  None
#
#
# - fL :
#  None
#
#
# - filenameroot :
#  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s
#
#
# - filepath :
#  C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s.easy.gz
#
#
# - fline :
#  None
#
#
# - fs :
#  500.0
#
#
# - good_init :
#  True
#
#
# - log :
#  ['capsule created: 2018-11-05 11:21']
#
#
# - np_acc :
#  [[    0.     0.     0.]
#  [    0.     0.     0.]
#  [    0.     0.     0.]
#  ...
#  [ -147.  8178. -3746.]
#  [ -147.  8178. -3746.]
#  [ -147.  8178. -3746.]]
#
#
# - np_eeg :
#  [[ 5706.549  9787.703 14372.541 ...  3827.381 10299.969  2095.318]
#  [ 5725.813  9811.545 14395.858 ...  3836.632 10319.377  2114.963]
#  [ 5743.933  9831.429 14416.791 ...  3852.892 10339.928  2131.748]
#  ...
#  [ 4710.627  7230.473 13397.552 ...  1661.682  9651.614  1771.021]
#  [ 4708.338  7225.323 13391.448 ...  1651.811  9646.13   1765.251]
#  [ 4716.015  7233.572 13401.176 ...  1652.05   9654.761  1772.594]]
#
#
# - np_eeg_original :
#  [[ 5706.549  9787.703 14372.541 ...  3827.381 10299.969  2095.318]
#  [ 5725.813  9811.545 14395.858 ...  3836.632 10319.377  2114.963]
#  [ 5743.933  9831.429 14416.791 ...  3852.892 10339.928  2131.748]
#  ...
#  [ 4710.627  7230.473 13397.552 ...  1661.682  9651.614  1771.021]
#  [ 4708.338  7225.323 13391.448 ...  1651.811  9646.13   1765.251]
#  [ 4716.015  7233.572 13401.176 ...  1652.05   9654.761  1772.594]]
#
#
# - np_markers :
#  [0. 0. 0. ... 0. 0. 0.]
#
#
# - np_stim :
#  []
#
#
# - np_time :
#  [0.00000e+00 2.00000e-03 4.00000e-03 ... 1.19992e+02 1.19994e+02
#  1.19996e+02]
#
#
# - num_channels :
#  32
#
#
# - offsets :
#  None
#
#
# - reference_electrodes :
#  None
#
#
# - sigmas :
#  None
#
#
# Capsule object created by anonymous on 2018-11-05 11:21 from file:
#
#             - C:\Users\roser.sanchez\Documents\Git\nepy_support\sampledata\20170807135459_W012_V1_EYC_noinfo_s.easy.gz
#
#         Current log is:
#
#             - ['capsule created: 2018-11-05 11:21']
#
#         So long and thanks for all the fish.
